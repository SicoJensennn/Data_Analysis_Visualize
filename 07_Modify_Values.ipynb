# %% [markdown]
# ## 1. Rename axis

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html#pandas.DataFrame.rename
# `DataFrame.rename(mapper=None, *, index=None, columns=None, axis=None, copy=None, inplace=False, level=None, errors='ignore')`

# %% [markdown]
# + mapper: dict-like or function. Dict-like or function transformations to apply to that axis’ values. Use either mapper and axis to specify the axis to target with mapper, or index and columns.

# %%
import pandas as pd
titanic = pd.read_csv("data/titanic.csv")
houses = pd.read_csv("data/kc_house_data.csv")
netflix = pd.read_csv("data/netflix_titles.csv",sep = "|", index_col = 0)
btc = pd.read_csv("data/coin_Bitcoin.csv")
countries = pd.read_csv("data/world-happiness-report-2021.csv").set_index("Country name")

# %%
countries.head()
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Finland          Western Europe         7.842                           0.032
# Denmark          Western Europe         7.620                           0.035
# Switzerland      Western Europe         7.571                           0.036
# Iceland          Western Europe         7.554                           0.059
# Netherlands      Western Europe         7.464                           0.027
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Finland              7.904         7.780                 10.775
# Denmark              7.687         7.552                 10.933
# Switzerland          7.643         7.500                 11.117
# Iceland              7.670         7.438                 10.878
# Netherlands          7.518         7.410                 10.932
#
#               Social support  Healthy life expectancy  \
# Country name
# ...

# %%
replace = {"Regional indicator": "Regional Indicator"}
countries.rename(columns = replace).head()
# Out:
#              Regional Indicator  Ladder score  Standard error of ladder score  \
# Country name
# Finland          Western Europe         7.842                           0.032
# Denmark          Western Europe         7.620                           0.035
# Switzerland      Western Europe         7.571                           0.036
# Iceland          Western Europe         7.554                           0.059
# Netherlands      Western Europe         7.464                           0.027
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Finland              7.904         7.780                 10.775
# Denmark              7.687         7.552                 10.933
# Switzerland          7.643         7.500                 11.117
# Iceland              7.670         7.438                 10.878
# Netherlands          7.518         7.410                 10.932
#
#               Social support  Healthy life expectancy  \
# Country name
# ...

# %%
change = {"France":"FR"}
countries.rename(index = change, inplace = True)
countries.sort_values("Country name")
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Afghanistan                           South Asia         2.523
# Albania               Central and Eastern Europe         5.117
# Algeria             Middle East and North Africa         4.887
# Argentina            Latin America and Caribbean         5.929
# Armenia       Commonwealth of Independent States         5.283
# ...                                          ...           ...
# Venezuela            Latin America and Caribbean         4.892
# Vietnam                           Southeast Asia         5.411
# Yemen               Middle East and North Africa         3.658
# Zambia                        Sub-Saharan Africa         4.073
# Zimbabwe                      Sub-Saharan Africa         3.145
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# ...

# %% [markdown]
# ## 2. Replace

# %%
titanic["sex"].replace("female", "Woman")
# Out:
# 0       Woman
# 1        male
# 2       Woman
# 3        male
# 4       Woman
#         ...
# 1304    Woman
# 1305    Woman
# 1306     male
# 1307     male
# 1308     male
# Name: sex, Length: 1309, dtype: object

# %% [markdown]
# When replace item with none, you must use `[None]`.

# %%
titanic["age"].replace(["?"], [None])
# Out:
# 0           29
# 1       0.9167
# 2            2
# 3           30
# 4           25
#          ...
# 1304      14.5
# 1305      None
# 1306      26.5
# 1307        27
# 1308        29
# Name: age, Length: 1309, dtype: object

# %% [markdown]
# ## 3. update values with `loc[]`

# %%
countries.loc["FR"]
# Out:
# Regional indicator                            Western Europe
# Ladder score                                            6.69
# Standard error of ladder score                         0.037
# upperwhisker                                           6.762
# lowerwhisker                                           6.618
# Logged GDP per capita                                 10.704
# Social support                                         0.942
# Healthy life expectancy                                 74.0
# Freedom to make life choices                           0.822
# Generosity                                            -0.147
# Perceptions of corruption                              0.571
# Ladder score in Dystopia                                2.43
# Explained by: Log GDP per capita                       1.421
# Explained by: Social support                           1.081
# Explained by: Healthy life expectancy                  0.804
# ...

# %%
countries.loc[["China","United States"],["upperwhisker","lowerwhisker"]]
# Out:
#                upperwhisker  lowerwhisker
# Country name
# China                 5.397         5.281
# United States         7.047         6.856

# %%
countries.loc[["Finland", "Denmark"],["Regional indicator"]] = "Scandinavia"
countries.head()
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Finland             Scandinavia         7.842                           0.032
# Denmark             Scandinavia         7.620                           0.035
# Switzerland      Western Europe         7.571                           0.036
# Iceland          Western Europe         7.554                           0.059
# Netherlands      Western Europe         7.464                           0.027
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Finland              7.904         7.780                 10.775
# Denmark              7.687         7.552                 10.933
# Switzerland          7.643         7.500                 11.117
# Iceland              7.670         7.438                 10.878
# Netherlands          7.518         7.410                 10.932
#
#               Social support  Healthy life expectancy  \
# Country name
# ...

# %%
countries.loc[["Finland", "Denmark"],["Regional indicator","Weather" ]] = ["Scandinavia", "Cold"]

# %%
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland              Scandinavia         7.842
# Denmark              Scandinavia         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %% [markdown]
# ## 4. make updates with `loc[]` and boolean masks

# %%
many_bedrooms = houses["bedrooms"] >= 10
many_bedrooms
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Name: bedrooms, Length: 21613, dtype: bool

# %%
houses.loc[many_bedrooms, ["price", "sqft_living"]]
# Out:
#            price  sqft_living
# 8757    520000.0         3000
# 13314  1148000.0         4590
# 15161   650000.0         3610
# 15870   640000.0         1620
# 19254   660000.0         2920

# %%
houses.loc[many_bedrooms, ["bedrooms"]] = "Greater than 9"

# %%
houses[many_bedrooms]
# Out:
#                id             date      price        bedrooms  bathrooms  \
# 8757   1773100755  20140821T000000   520000.0  Greater than 9       3.00
# 13314   627300145  20140814T000000  1148000.0  Greater than 9       5.25
# 15161  5566100170  20141029T000000   650000.0  Greater than 9       2.00
# 15870  2402100895  20140625T000000   640000.0  Greater than 9       1.75
# 19254  8812401450  20141229T000000   660000.0  Greater than 9       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 8757          3000      4960     2.0           0     0  ...      7
# 13314         4590     10920     1.0           0     2  ...      9
# 15161         3610     11914     2.0           0     0  ...      7
# 15870         1620      6000     1.0           0     0  ...      7
# 19254         2920      3745     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# ...

# %% [markdown]
# We can access label through rows.
