# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv("data/titanic.csv")
titanic["age"] = pd.to_numeric(titanic["age"], errors="coerce")
houses = pd.read_csv("data/kc_house_data.csv")
ufo = pd.read_csv("data/nuforc_reports.csv", parse_dates=['date_time', "posted"])

# %% [markdown]
# ## 1. Pandas Plot

# %% [markdown]
# `Dataframe.plot`: It will make a plot for every single series.

# %%
houses.head(3)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
#
# ...

# %%
houses[["sqft_living", "sqft_lot"]].sort_values("sqft_living", ascending = False).head(10).plot(kind = "bar")
# Out:
# <Axes: >

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("ggplot")

# %%
houses[["sqft_living", "sqft_living15"]].sort_values("sqft_living", ascending = False).head(10).plot(kind = "bar")
# Out:
# <Axes: >

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html#pandas.DataFrame.plot

# %%
titanic.sex.value_counts().plot(kind = "bar", title = "Titanic Gender Distribution")
# Out:
# <Axes: title={'center': 'Titanic Gender Distribution'}, xlabel='sex'>

# %%
ufo["month"] = ufo["date_time"].dt.month

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87888 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84951 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  datetime64[ns]
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
#  12  month           86938 non-null  float64
# dtypes: datetime64[ns](2), float64(3), object(8)
# memory usage: 8.7+ MB

# %%
ufo.month.value_counts().sort_index().plot(
    kind = "bar",
    title = "UFO Sighting By Month", 
    xlabel = "month",
    ylabel = "Occurance", 
    fontsize = "15")
plt.xlabel("month", fontsize = 20)
plt.ylabel("occurance", fontsize = 20)
# Out:
# Text(0, 0.5, 'occurance')

# %% [markdown]
# `fontsize` only controls xticks and yticks.

# %% [markdown]
# ## 2. Rename

# %% [markdown]
# Rename the xlabel.

# %%
um = ufo.month.value_counts().sort_index()
um.rename({1:"Jan", 2:"Feb", 3:"Mar", 4:"Apr", 5:"May", 6:"Jun",7:"Jul", 8:"Aug", 9:"Sep",10:"Oct",11:"Nov", 12:"Dec"}, inplace = True)

# %%
um.plot(kind = "bar")
# Out:
# <Axes: xlabel='month'>

# %%
salaries = pd.read_csv("data/Salaries.csv", low_memory=False)

# %%
salaries.head(3)
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2    GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3  ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# 1  2011    NaN  San Francisco    NaN
# 2  2011    NaN  San Francisco    NaN

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
salaries["BasePay"] = pd.to_numeric(salaries["BasePay"], errors="coerce").fillna(0)
salaries["OvertimePay"] = pd.to_numeric(salaries["OvertimePay"], errors="coerce").fillna(0)
salaries["OtherPay"] = pd.to_numeric(salaries["OtherPay"], errors="coerce").fillna(0)

# %%
df = salaries[["EmployeeName", "BasePay", "OvertimePay", "OtherPay"]]

# %%
df.set_index("EmployeeName", inplace = True)

# %%
df.head(10).plot(kind = "bar")
# Out:
# <Axes: xlabel='EmployeeName'>

# %% [markdown]
# Or I can simply use `plot.bar()`

# %%
df["BasePay"].sort_values(ascending = False).head().plot.bar()
# Out:
# <Axes: xlabel='EmployeeName'>

# %%
df.sort_values("OvertimePay", ascending = False).head(6).plot.barh(stacked = True)
# Out:
# <Axes: ylabel='EmployeeName'>

# %% [markdown]
# **`Stacked`**:Plot stacked

# %% [markdown]
# ## 3. Histogram

# %%
df["BasePay"].plot(kind = "hist", bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind = "hist", bins = 100)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Make a separate histgram for every piece, every column in that data frame.

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'BasePay'}>,
#         <Axes: title={'center': 'OvertimePay'}>],
#        [<Axes: title={'center': 'OtherPay'}>, <Axes: >]], dtype=object)

# %% [markdown]
# ## 4. Box Plots

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.boxplot.html

# %%
df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# The box extends from the first quartile (Q1) to the third quartile (Q3) of the data, with a line at the median.

# %%
df.boxplot(showfliers = False)
# Out:
# <Axes: >

# %% [markdown]
# ## 5. Line Plots

# %%
ufo.head(3)
# Out:
#                                              summary        city state  \
# 0  My wife was driving southeast on a fairly popu...     Chester    VA
# 1  I think that I may caught a UFO on the NBC Nig...  Rocky Hill    CT
# 2  I woke up late in the afternoon 3:30-4pm. I we...         NaN   NaN
#
#             date_time   shape     duration  \
# 0 2019-12-12 18:43:00   light    5 seconds
# 1 2019-03-22 18:30:00  circle  3-5 seconds
# 2                 NaT     NaN          NaN
#
#                                                stats  \
# 0  Occurred : 12/12/2019 18:43  (Entered as : 12/...
# 1  Occurred : 3/22/2019 18:30  (Entered as : 03/2...
# 2  Occurred : 4/1/2019 15:45  (Entered as : April...
#
#                                          report_link  \
# 0  http://www.nuforc.org/webreports/151/S151739.html
# 1  http://www.nuforc.org/webreports/145/S145297.html
# 2  http://www.nuforc.org/webreports/145/S145556.html
#
# ...

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87888 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84951 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  datetime64[ns]
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: datetime64[ns](2), float64(2), object(8)
# memory usage: 8.1+ MB

# %%
ufo["month"] = ufo.date_time.dt.month
ufo["year"] = ufo.date_time.dt.year

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87888 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84951 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  datetime64[ns]
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
#  12  month           86938 non-null  float64
#  13  year            86938 non-null  float64
# dtypes: datetime64[ns](2), float64(4), object(8)
# memory usage: 9.4+ MB

# %%
ufo.year.value_counts().sort_index().plot(kind = "line",linewidth = 5)
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ## 6. Scatter plot

# %%
houses.plot.scatter(x = "bedrooms", y = "bathrooms", marker = "+",color = "#52796f")
# Out:
# <Axes: xlabel='bedrooms', ylabel='bathrooms'>

# %%
ufo[ufo["state"] == "UT"].year.value_counts().sort_index().plot(color = "#738290",label = "UT")
ufo[ufo["state"] == "OR"].year.value_counts().sort_index().plot(color = "#a1b5d8",label = "OR")
ufo[ufo["state"] == "CA"].year.value_counts().sort_index().plot(color = "#7ebc89",label = "CA")
ufo[ufo["state"] == "AZ"].year.value_counts().sort_index().plot(color = "#ffb627",label = "AZ")
plt.legend()

# %%
ufo[ufo["shape"] == "light"].year.value_counts().sort_index().plot(color = "#738290", label = "light")
ufo[ufo["shape"] == "fireball"].year.value_counts().sort_index().plot(color = "#a1b5d8", label = "fireball")
ufo[ufo["shape"] == "circle"].year.value_counts().sort_index().plot(color = "#7ebc89",label = "circle")
ufo[ufo["shape"] == "triangle"].year.value_counts().sort_index().plot(color = "#f5cb5c",label = "triangle")
plt.xlim(2000, 2018)
plt.legend()

# %% [markdown]
# ## Automatic Subplots

# %%
df.plot(kind = "hist", subplots = True, sharex = False, figsize=(5,8))
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>], dtype=object)

# %%
axs = df.plot(kind = "hist", subplots = True, sharex = False, layout = (1,3),figsize=(12,4), bins = 30)
axs[0][1].set_title("Overtimerpay")
axs[0][1].set_xlim(0,100000)
axs[0][2].set_title("Otherpay")
axs[0][2].set_xlim(0,80000)
axs[0][0].set_title("Basepay")
axs[0][0].set_xlim(0,250000)
# Out:
# (0.0, 250000.0)

# %%
fig, axs = plt.subplots(1,2)
ufo.year.value_counts().sort_index().plot(ax=axs[0])
axs[0].set_title("Sightings By Year")
ufo.month.value_counts().sort_index().plot(kind="bar", ax=axs[1])
axs[1].set_title("Sightings By Month")
# Out:
# Text(0.5, 1.0, 'Sightings By Month')

# %% [markdown]
# ## 8. Export Fig

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.savefig.html#matplotlib.pyplot.savefig

# %%
fig, axs = plt.subplots(1,2)
ufo.year.value_counts().sort_index().plot(ax=axs[0])
axs[0].set_title("Sightings By Year")
ufo.month.value_counts().sort_index().plot(kind="bar", ax=axs[1])
axs[1].set_title("Sightings By Month")
plt.savefig("ufo")
